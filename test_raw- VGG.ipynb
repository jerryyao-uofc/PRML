# %% [markdown]
# ##### Import data

# %%
from util_copy import load_fabric_data, extract_label_grouping, extract_label_grouping, load_fabric_images
import numpy as np
from matplotlib import image

# %%
path = r"C:/Users/Administrator/Desktop/PRML/Project/fabric_data/label_json/**/**.json"

fids, fdata = load_fabric_data(path)
ftype1, ftype2 = extract_label_grouping(fdata)

# %%
path = r"C:/Users/Administrator/Desktop/PRML/Project/fabric_data/temp/"
labels, imgs = load_fabric_images(path, fids, fdata, ftype2)
# Out:
# C:/Users/Administrator/Desktop/PRML/Project/fabric_data/temp/**/**.jpg

# %%
print(fdata)
# Out:
# [{'flaw_type': 4, 'bbox': {'x0': 125, 'x1': 188, 'y0': 171, 'y1': 230}}, {'flaw_type': 4, 'bbox': {'x0': 79, 'x1': 148, 'y0': 170, 'y1': 231}}, {'flaw_type': 11, 'bbox': {'x0': 145, 'x1': 256, 'y0': 162, 'y1': 238}}, {'flaw_type': 11, 'bbox': {'x0': 145, 'x1': 256, 'y0': 163, 'y1': 238}}, {'flaw_type': 11, 'bbox': {'x0': 165, 'x1': 236, 'y0': 170, 'y1': 230}}, {'flaw_type': 4, 'bbox': {'x0': 41, 'x1': 359, 'y0': 142, 'y1': 259}}, {'flaw_type': 4, 'bbox': {'x0': 250, 'x1': 367, 'y0': 148, 'y1': 253}}, {'flaw_type': 4, 'bbox': {'x0': 127, 'x1': 273, 'y0': 154, 'y1': 247}}, {'flaw_type': 4, 'bbox': {'x0': 128, 'x1': 273, 'y0': 156, 'y1': 245}}, {'flaw_type': 4, 'bbox': {'x0': 129, 'x1': 272, 'y0': 155, 'y1': 246}}, {'flaw_type': 4, 'bbox': {'x0': 116, 'x1': 273, 'y0': 160, 'y1': 241}}, {'flaw_type': 4, 'bbox': {'x0': 143, 'x1': 258, 'y0': 158, 'y1': 243}}, {'flaw_type': 4, 'bbox': {'x0': 147, 'x1': 254, 'y0': 160, 'y1': 240}}, {'flaw_type': 4, 'bbox': {'x0': 0, 'x1': 540, 'y0': 115, 'y1': 285}}, {'flaw_type': 4, 'bbox': {'x0': 0, 'x1': 415, 'y0': 153, 'y1': 247}}, {'flaw_type': 4, 'bbox': {'x0': 99, 'x1': 302, 'y0': 115, 'y1': 285}}, {'flaw_type': 4, 'bbox': {'x0': 97, 'x1': 303, 'y0': 158, 'y1': 243}}, {'flaw_type': 4, 'bbox': {'x0': 128, 'x1': 272, 'y0': 151, 'y1': 250}}, {'flaw_type': 4, 'bbox': {'x0': 122, 'x1': 278, 'y0': 165, 'y1': 235}}, {'flaw_type': 4, 'bbox': {'x0': 138, 'x1': 263, 'y0': 162, 'y1': 238}}, {'flaw_type': 4, 'bbox': {'x0': 46, 'x1': 354, 'y0': 148, 'y1': 253}}, {'flaw_type': 4, 'bbox': {'x0': 64, 'x1': 336, 'y0': 159, 'y1': 242}}, {'flaw_type': 4, 'bbox': {'x0': 0, 'x1': 655, 'y0': 126, 'y1': 274}}, {'flaw_type': 11, 'bbox': {'x0': 2, 'x1': 80, 'y0': 159, 'y1': 241}}, {'flaw_type': 4, 'bbox': {'x0': 48, 'x1': 352, 'y0': 135, 'y1': 265}}, {'flaw_type': 4, 'bbox': {'x0': 94, 'x1': 211, 'y0': 134, 'y1': 267}}, {'flaw_type': 4, 'bbox': {'x0': 73, 'x1': 328, 'y0': 131, 'y1': 269}}, {'flaw_type': 4, 'bbox': {'x0': 67, 'x1': 333, 'y0': 132, 'y1': 268}}, {'flaw_type': 4, 'bbox': {'x0': 118, 'x1': 283, 'y0': 142, 'y1': 258}}, {'flaw_type': 4, 'bbox': {'x0': 144, 'x1': 256, 'y0': 143, 'y1': 257}}, {'flaw_type': 4, 'bbox': {'x0': 106, 'x1': 295, 'y0': 108, 'y1': 292}}, {'flaw_type': 4, 'bbox': {'x0': 112, 'x1': 288, 'y0': 153, 'y1': 247}}, {'flaw_type': 4, 'bbox': {'x0': 227, 'x1': 381, 'y0': 142, 'y1': 274}}, {'flaw_type': 4, 'bbox': {'x0': 51, 'x1': 349, 'y0': 81, 'y1': 319}}, {'flaw_type': 4, 'bbox': {'x0': 124, 'x1': 276, 'y0': 108, 'y1': 293}}, {'flaw_type': 11, 'bbox': {'x0': 109, 'x1': 291, 'y0': 142, 'y1': 259}}, {'flaw_type': 11, 'bbox': {'x0': 59, 'x1': 397, 'y0': 76, 'y1': 325}}, {'flaw_type': 0, 'bbox': {'x0': 1, 'x1': 37, 'y0': 137, 'y1': 264}}, {'flaw_type': 12, 'bbox': {'x0': 235, 'x1': 308, 'y0': 113, 'y1': 287}}, {'flaw_type': 0, 'bbox': {'x0': 221, 'x1': 400, 'y0': 0, 'y1': 1894}}, {'flaw_type': 11, 'bbox': {'x0': 81, 'x1': 173, 'y0': 150, 'y1': 251}}, {'flaw_type': 11, 'bbox': {'x0': 131, 'x1': 269, 'y0': 77, 'y1': 378}}, {'flaw_type': 11, 'bbox': {'x0': 266, 'x1': 396, 'y0': 233, 'y1': 381}}, {'flaw_type': 11, 'bbox': {'x0': 145, 'x1': 255, 'y0': 273, 'y1': 400}}, {'flaw_type': 11, 'bbox': {'x0': 186, 'x1': 317, 'y0': 74, 'y1': 326}}, {'flaw_type': 11, 'bbox': {'x0': 170, 'x1': 230, 'y0': 16, 'y1': 77}}, {'flaw_type': 11, 'bbox': {'x0': 113, 'x1': 287, 'y0': 44, 'y1': 356}}, {'flaw_type': 11, 'bbox': {'x0': 0, 'x1': 401, 'y0': 0, 'y1': 580}}, {'flaw_type': 11, 'bbox': {'x0': 166, 'x1': 235, 'y0': 171, 'y1': 230}}, {'flaw_type': 6, 'bbox': {'x0': 163, 'x1': 238, 'y0': 213, 'y1': 294}}, {'flaw_type': 6, 'bbox': {'x0': 170, 'x1': 231, 'y0': 271, 'y1': 336}}, {'flaw_type': 4, 'bbox': {'x0': 36, 'x1': 365, 'y0': 142, 'y1': 258}}, {'flaw_type': 4, 'bbox': {'x0': 0, 'x1': 589, 'y0': 123, 'y1': 278}}, {'flaw_type': 6, 'bbox': {'x0': 262, 'x1': 325, 'y0': 170, 'y1': 231}}, {'flaw_type': 0, 'bbox': {'x0': 170, 'x1': 231, 'y0': 168, 'y1': 232}}, {'flaw_type': 11, 'bbox': {'x0': 149, 'x1': 251, 'y0': 167, 'y1 ...

# %%
print(len(labels))
print(imgs[0])
# Out:
# 3371
# [[[130 130 128 155 147 171]
#   [139 137 138 151 150 168]
#   [147 145 148 146 154 167]
#   ...
#   [ 57  46  24  92  87  29]
#   [ 73  51  28  83  64  34]
#   [124  89  69  76  47  51]]
#
#  [[139 141 140 162 153 174]
#   [143 144 146 157 155 168]
#   [148 148 150 151 155 166]
#   ...
#   [ 69  61  38 121 124  69]
#   [ 58  41  15 113 100  56]
#   [ 69  39  15  88  63  33]]
#
#  [[143 147 150 160 149 166]
#   [145 149 152 156 153 162]
#   [150 151 156 153 156 161]
#   ...
#   [102 100  75 153 160 116]
#   [ 90  79  49 140 133  79]
#   [ 75  55  22 126 106  47]]
#
#  ...
#
#  [[ 56  19  13  76  21  24]
#   [ 55  16  11  77  28  31]
#   [ 57  18  13  70  31  32]
#   ...
#   [208 213 219 210 213 206]
#   [208 218 220 222 223 228]
#   [200 210 211 216 213 234]]
#
#  [[ 74  35  28 103  31  34]
#   [ 69  30  23 103  37  39]
#   [ 72  31  25  95  39  40]
#   ...
#   [191 200 209 212 212 212]
#   [220 231 237 209 209 221]
#   [196 210 213 213 210 237]]
#
#  [[ 87  49  40 122  36  37]
#   [ 82  42  34 123  41  43]
#   [ 85  45  37 115  43  46]
#   ...
#   [185 193 204 214 212 223]
#   [195 208 216 215 212 233]
#   [193 208 215 217 216 248]]]

# %%
n_samples = len(imgs)
print("Number of samples:", n_samples)
# Out:
# Number of samples: 3371

# %%
print(imgs[1230].shape)
# Out:
# (400, 400, 6)

# %% [markdown]
# ##### Padding
# - https://blog.csdn.net/wuzqChom/article/details/74785643
# - https://stackoverflow.com/questions/47697622/cnn-image-resizing-vs-padding-keeping-aspect-ratio-or-not/49882055#49882055
# - https://stackoverflow.com/questions/43391205/add-padding-to-images-to-get-them-into-the-same-shape

# %%
import cv2

# %%
imgs = [cv2.resize(img,(200, 200)) for img in imgs]

# %% [markdown]
# ##### Split data

# %%
from sklearn.model_selection import train_test_split

# %%
train_images, test_images, train_labels, test_labels = train_test_split(imgs, labels, test_size=0.3, random_state=1)

# %%
print(train_images.type)

# %%
print("#Training data: {}\n#Testing data: {}\n#Class: {}".format(len(train_images), len(test_images), len(set(train_labels))))
# Out:
# #Training data: 2359
# #Testing data: 1012
# #Class: 9

# %% [markdown]
# ##### Normalize data

# %%
train_images, test_images, train_labels, test_labels = np.array(train_images), np.array(test_images), np.array(train_labels), np.array(test_labels)
train_images, test_images = train_images / 255.0, test_images / 255.0

# %%
train_images.shape
# Out:
# (2359, 200, 200, 6)

# %% [markdown]
# ##### Generate fake data

# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt
import keras,os
from keras.models import Sequential
from keras.layers import Dense, Conv2D, MaxPool2D , Flatten
from keras.preprocessing.image import ImageDataGenerator
import numpy as np


input_shape = (200, 200, 6)

# %%
# https://towardsdatascience.com/step-by-step-vgg16-implementation-in-keras-for-beginners-a833c686ae6c


model = Sequential()
model.add(Conv2D(input_shape=input_shape,filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(Conv2D(filters=64,kernel_size=(3,3),padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=128, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=256, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(Conv2D(filters=512, kernel_size=(3,3), padding="same", activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(Flatten())
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=4096,activation="relu"))
model.add(Dense(units=9, activation="softmax"))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_13 (Conv2D)           (None, 200, 200, 64)      3520
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 200, 200, 64)      36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 100, 100, 64)      0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 100, 100, 128)     73856
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 100, 100, 128)     147584
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 50, 50, 128)       0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 50, 50, 256)       295168
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 50, 50, 256)       590080
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 50, 50, 256)       590080
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 25, 25, 256)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 25, 25, 512)       1180160
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 25, 25, 512)       2359808
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 25, 25, 512)       2359808
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 12, 12, 512)       0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 12, 12, 512)       2359808
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 12, 12, 512)       2359808
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 12, 12, 512)       2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 18432)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4096)              75501568
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_5 (Dense)              (None, 9)                 36873
# =================================================================
# Total params: 107,036,169
# Trainable params: 107,036,169
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 74/74 [==============================] - ETA: 0s - loss: 2.8353 - accuracy: 0.1780

# %% [markdown]
# ##### Create model
# - https://www.tensorflow.org/tutorials/images/classification

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))

# %% [markdown]
# ##### Testing

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

# %%
print(test_acc)
